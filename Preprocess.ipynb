# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('sustainability.csv')

# %%
df.head()
# Out:
#   Sl. No.           State/UT  Wind Power - (MW) @ 120m  \
# 0       1     Andhra Pradesh                   74906.0
# 1       2  Arunachal Pradesh                     274.0
# 2       3              Assam                     246.0
# 3       4              Bihar                    3650.0
# 4       5       Chhattisgarh                     348.0
#
#    Small Hydro Power - (MW)  Bio-Energy - Biomass Power - (MW)  \
# 0                    409.32                              578.0
# 1                   2064.92                                8.0
# 2                    201.99                              212.0
# 3                    526.98                              619.0
# 4                   1098.20                              236.0
#
#    Bio-Energy - Bagase Cogeneration - (MW)  \
# 0                                    300.0
# 1                                      NaN
# 2                                      NaN
# 3                                    300.0
# ...

# %%
print(df.isnull())
# Out:
#     Sl. No.  State/UT  Wind Power - (MW) @ 120m  Small Hydro Power - (MW)  \
# 0     False     False                     False                     False
# 1     False     False                     False                     False
# 2     False     False                     False                     False
# 3     False     False                     False                     False
# 4     False     False                     False                     False
# 5     False     False                     False                     False
# 6     False     False                     False                     False
# 7     False     False                     False                     False
# 8     False     False                     False                     False
# 9     False     False                     False                     False
# 10    False     False                     False                     False
# 11    False     False                     False                     False
# ...

# %%
print(df.notnull())
# Out:
#     Sl. No.  State/UT  Wind Power - (MW) @ 120m  Small Hydro Power - (MW)  \
# 0      True      True                      True                      True
# 1      True      True                      True                      True
# 2      True      True                      True                      True
# 3      True      True                      True                      True
# 4      True      True                      True                      True
# 5      True      True                      True                      True
# 6      True      True                      True                      True
# 7      True      True                      True                      True
# 8      True      True                      True                      True
# 9      True      True                      True                      True
# 10     True      True                      True                      True
# 11     True      True                      True                      True
# ...

# %%
df.fillna(0)
# Out:
#    Sl. No.                          State/UT  Wind Power - (MW) @ 120m  \
# 0        1                    Andhra Pradesh                   74906.0
# 1        2                 Arunachal Pradesh                     274.0
# 2        3                             Assam                     246.0
# 3        4                             Bihar                    3650.0
# 4        5                      Chhattisgarh                     348.0
# 5        6                               Goa                       8.0
# 6        7                           Gujarat                  142560.0
# 7        8                           Haryana                     419.0
# 8        9                  Himachal Pradesh                     151.0
# 9       10  UT of Jammu & Kashmir and Ladakh                       3.0
# 10      11                         Jharkhand                       0.0
# 11      12                         Karnataka                  124155.0
# ...

# %%
df.fillna(method="pad")
# Out:
#    Sl. No.                          State/UT  Wind Power - (MW) @ 120m  \
# 0        1                    Andhra Pradesh                   74906.0
# 1        2                 Arunachal Pradesh                     274.0
# 2        3                             Assam                     246.0
# 3        4                             Bihar                    3650.0
# 4        5                      Chhattisgarh                     348.0
# 5        6                               Goa                       8.0
# 6        7                           Gujarat                  142560.0
# 7        8                           Haryana                     419.0
# 8        9                  Himachal Pradesh                     151.0
# 9       10  UT of Jammu & Kashmir and Ladakh                       3.0
# 10      11                         Jharkhand                       0.0
# 11      12                         Karnataka                  124155.0
# ...

# %%
numeric_columns = ['Total - (MW)']  # Specify columns containing numeric data
df[numeric_columns] = df[numeric_columns].astype(float)
